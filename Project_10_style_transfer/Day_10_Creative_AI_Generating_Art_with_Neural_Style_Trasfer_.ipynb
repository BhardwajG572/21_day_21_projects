# %% [markdown]
# # Task
# Load the file "https://github.com/AshishJangra27/Face-Generator-with-GAN/blob/main/generator_700.h5" from the GitHub repository "https://github.com/AshishJangra27/Face-Generator-with-GAN.git".

# %% [markdown]
# ## Clone repository
#
# ### Subtask:
# Clone the specified GitHub repository to access the file.

# %% [markdown]
# **Reasoning**:
# Clone the GitHub repository using the git clone command.

# %%
# !git clone https://github.com/AshishJangra27/Face-Generator-with-GAN.git
# Out:
# Cloning into 'Face-Generator-with-GAN'...
# remote: Enumerating objects: 34, done.
# remote: Counting objects: 100% (34/34), done.
# remote: Compressing objects: 100% (33/33), done.
# remote: Total 34 (delta 10), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (34/34), 160.27 MiB | 17.43 MiB/s, done.
# Resolving deltas: 100% (10/10), done.
# Updating files: 100% (10/10), done.

# %% [markdown]
# ## Load file
#
# ### Subtask:
# Load the specified file from the cloned repository.

# %% [markdown]
# **Reasoning**:
# Import the necessary library and load the model from the specified file path.

# %%
import tensorflow as tf

model = tf.keras.models.load_model('Face-Generator-with-GAN/generator_700.h5')
# Out:
# WARNING:absl:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.

# %% [markdown]
# ## Summary:
#
# ### Data Analysis Key Findings
#
# * The GitHub repository "https://github.com/AshishJangra27/Face-Generator-with-GAN.git" was successfully cloned.
# * The file "generator_700.h5" was successfully loaded from the cloned repository using `tf.keras.models.load_model()`.
#
# ### Insights or Next Steps
#
# * The loaded model can now be used for tasks such as generating faces or further analysis.
# * Investigate the warning about the missing training configuration to understand its potential implications for using the loaded model.
