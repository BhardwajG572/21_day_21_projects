# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import seaborn as sns

sns.set_style('darkgrid')

# %%
df = pd.read_csv('/content/drive/MyDrive/Data_set_GFG/Project-2_GFG/netflix_titles.csv')
display(df.head())
# Out:
#   show_id     type  title           director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie   7:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 cast        country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#           date_added  release_year rating   duration  \
# 0    August 14, 2020          2020  TV-MA  4 Seasons
# 1  December 23, 2016          2016  TV-MA     93 min
# 2  December 20, 2018          2011      R     78 min
# 3  November 16, 2017          2009  PG-13     80 min
# ...

# %%
df.head()
# Out:
#   show_id     type  title           director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie   7:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 cast        country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#           date_added  release_year rating   duration  \
# 0    August 14, 2020          2020  TV-MA  4 Seasons
# 1  December 23, 2016          2016  TV-MA     93 min
# 2  December 20, 2018          2011      R     78 min
# 3  November 16, 2017          2009  PG-13     80 min
# ...

# %%
df.shape
# Out:
# (7787, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7787 entries, 0 to 7786
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       7787 non-null   object
#  1   type          7787 non-null   object
#  2   title         7787 non-null   object
#  3   director      5398 non-null   object
#  4   cast          7069 non-null   object
#  5   country       7280 non-null   object
#  6   date_added    7777 non-null   object
#  7   release_year  7787 non-null   int64
#  8   rating        7780 non-null   object
#  9   duration      7787 non-null   object
#  10  listed_in     7787 non-null   object
#  11  description   7787 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 730.2+ KB

# %%
df.isna().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2389
# cast             718
# country          507
# date_added        10
# release_year       0
# rating             7
# duration           0
# listed_in          0
# description        0
# dtype: int64

# %% [markdown]
# Interpretation of  .info():
#
# We have 7787 entries(titles)
# key problem : The date_added column is of type object (a string) , not a datetime object. we cannot perfor time based analysis until this is corrected.
#
# Missing valuse : director , cast , country , date_added , and rating all have missing values , director has the most significant number of nulls
#
# ```
# # This is formatted as code
# ```

# %%
df.describe()
# Out:
#        release_year
# count   7787.000000
# mean    2013.932580
# std        8.757395
# min     1925.000000
# 25%     2013.000000
# 50%     2017.000000
# 75%     2018.000000
# max     2021.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7787 entries, 0 to 7786
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       7787 non-null   object
#  1   type          7787 non-null   object
#  2   title         7787 non-null   object
#  3   director      5398 non-null   object
#  4   cast          7069 non-null   object
#  5   country       7280 non-null   object
#  6   date_added    7777 non-null   object
#  7   release_year  7787 non-null   int64
#  8   rating        7780 non-null   object
#  9   duration      7787 non-null   object
#  10  listed_in     7787 non-null   object
#  11  description   7787 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 730.2+ KB

# %%
# fixing the date is must
# we can't perform Time series analysis :
# data cleaning & data transformation
#

# %%
df.head(2)
# Out:
#   show_id     type title           director  \
# 0      s1  TV Show    3%                NaN
# 1      s2    Movie  7:19  Jorge Michel Grau
#
#                                                 cast country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico
#
#           date_added  release_year rating   duration  \
# 0    August 14, 2020          2020  TV-MA  4 Seasons
# 1  December 23, 2016          2016  TV-MA     93 min
#
#                                            listed_in  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
#
#                                          description
# 0  In a future where the elite inhabit an island ...
# 1  After a devastating earthquake hits Mexico Cit...

# %%
# if i want to fill the director
# E
df['director'] = df['director'].fillna("Unknown")  # inpute the director column
df['cast'] = df['cast'].fillna("Unknown")

# %%
df.isna().sum()
# Out:
# show_id           0
# type              0
# title             0
# director          0
# cast              0
# country         507
# date_added       10
# release_year      0
# rating            7
# duration          0
# listed_in         0
# description       0
# dtype: int64

# %%
mode_country = df['country'].mode()[0]  # imputing the data
df['country']=df['country'].fillna(mode_country)

# %%
df.isna().sum()
# Out:
# show_id          0
# type             0
# title            0
# director         0
# cast             0
# country          0
# date_added      10
# release_year     0
# rating           7
# duration         0
# listed_in        0
# description      0
# dtype: int64

# %%
df.dropna(subset=['date_added','rating'],inplace = True)

# %%
df.isna().sum()
# Out:
# show_id         0
# type            0
# title           0
# director        0
# cast            0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        0
# listed_in       0
# description     0
# dtype: int64

# %%
df['date_added']
# Out:
# 0          August 14, 2020
# 1        December 23, 2016
# 2        December 20, 2018
# 3        November 16, 2017
# 4          January 1, 2020
#                ...
# 7782      October 19, 2020
# 7783         March 2, 2019
# 7784    September 25, 2020
# 7785      October 31, 2020
# 7786         March 1, 2020
# Name: date_added, Length: 7770, dtype: object

# %%
# In this we have to parse it :

# %%
df['date_added'] = pd.to_datetime(df['date_added'],format='mixed' , dayfirst = False)

# %% [markdown]
# *   format = 'mixed' : This argument tells pandas to infer the date format automatically . This is helpful when the date strings in the column have different formats
# *   dayFirst = False : This argument specifies that when the date format is ambiguous (e.g : 01/02/2023 ) it should be interpretd as month first (january 2nd) rather than day first (FEBrurary 1st)

# %%
df['date_added']
# Out:
# 0      2020-08-14
# 1      2016-12-23
# 2      2018-12-20
# 3      2017-11-16
# 4      2020-01-01
#           ...
# 7782   2020-10-19
# 7783   2019-03-02
# 7784   2020-09-25
# 7785   2020-10-31
# 7786   2020-03-01
# Name: date_added, Length: 7770, dtype: datetime64[ns]

# %%
# Now extract month and year

# %%
df['year_added'] = df['date_added'].dt.year
df['month_added'] = df['date_added'].dt.month

# %%
df.head(2)
# Out:
#   show_id     type title           director  \
# 0      s1  TV Show    3%            Unknown
# 1      s2    Movie  7:19  Jorge Michel Grau
#
#                                                 cast country date_added  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil 2020-08-14
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico 2016-12-23
#
#    release_year rating   duration  \
# 0          2020  TV-MA  4 Seasons
# 1          2016  TV-MA     93 min
#
#                                            listed_in  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
#
#                                          description  year_added  month_added
# 0  In a future where the elite inhabit an island ...        2020            8
# 1  After a devastating earthquake hits Mexico Cit...        2016           12

# %% [markdown]
# # Exploratory Data Anlsysi Visualization 🇰
# ### 4.1  : What is the distributin of content type ?

# %%
plt.figure(figsize = (8,6))
type_counts = df['type'].value_counts()
plt.pie(type_counts,labels = type_counts.index,autopct = '%1.1f%%')
plt.title('Distribution of Content Types')
plt.show()

# %% [markdown]
# ### 4.2 :  How has content been added over time ?

# %%
content_added_over_time = df.groupby(['year_added','type']).size().unstack().fillna(0)
plt.figure(figsize = (10,6))

sns.lineplot(data=content_added_over_time)

plt.xlabel('Year Added')
plt.ylabel('Number of Content Added')
plt.title('Content Added Over Time')
plt.legend(title = 'Content Type')
plt.show()

# %%
content_added_over_time
# Out:
# type         Movie  TV Show
# year_added
# 2008           1.0      1.0
# 2009           2.0      0.0
# 2010           1.0      0.0
# 2011          13.0      0.0
# 2012           3.0      0.0
# 2013           6.0      5.0
# 2014          19.0      6.0
# 2015          58.0     30.0
# 2016         256.0    184.0
# 2017         861.0    361.0
# 2018        1255.0    429.0
# 2019        1497.0    656.0
# 2020        1312.0    697.0
# 2021          88.0     29.0

# %% [markdown]
# The plot shows a significant increase in both movies and TV shows added to Netflix over the years, with a sharp decline in 2021. This indicates a period of rapid expansion up until 2020.
#
# The peak in 2019 and 2020 suggests a large influx of content during those years. The dip in 2021 could be due to various factors, such as the impact of the COVID-19 pandemic on production or a shift in content acquisition strategy. TV shows show a more consistent upward trend compared to movies, which fluctuate more.

# %% [markdown]
# ### 4.3 What are the most popular genres ?

# %%
df.head(2)
# Out:
#   show_id     type title           director  \
# 0      s1  TV Show    3%            Unknown
# 1      s2    Movie  7:19  Jorge Michel Grau
#
#                                                 cast country date_added  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil 2020-08-14
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico 2016-12-23
#
#    release_year rating   duration  \
# 0          2020  TV-MA  4 Seasons
# 1          2016  TV-MA     93 min
#
#                                            listed_in  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
#
#                                          description  year_added  month_added
# 0  In a future where the elite inhabit an island ...        2020            8
# 1  After a devastating earthquake hits Mexico Cit...        2016           12

# %% [markdown]
#  we are getting/extracting  the genres from listed_in ?
#  1. split the string in each row into a list of genres
#  2. Explode the dataframe so that each genre in the list gets its own row , duplicating the other information for that title . This allows us
#  to perform a value_counts() on the genres.

# %%
genres = df.assign(genre=df['listed_in'].str.split(', ')).explode('genre')
genres
# Out:
#      show_id     type                                    title  \
# 0         s1  TV Show                                       3%
# 0         s1  TV Show                                       3%
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                     7:19
# 1         s2    Movie                                     7:19
# ...      ...      ...                                      ...
# 7784   s7785    Movie                        Zulu Man in Japan
# 7785   s7786  TV Show                    Zumbo's Just Desserts
# 7785   s7786  TV Show                    Zumbo's Just Desserts
# 7786   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
# 7786   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                director                                               cast  \
# 0               Unknown  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
top_genres_count  = genres['genre'].value_counts().reset_index()
top_genres_count.columns = ['genre','count']
top_genres_count
# Out:
#                            genre  count
# 0           International Movies   2437
# 1                         Dramas   2105
# 2                       Comedies   1471
# 3         International TV Shows   1197
# 4                  Documentaries    786
# 5             Action & Adventure    721
# 6                      TV Dramas    703
# 7             Independent Movies    673
# 8       Children & Family Movies    532
# 9                Romantic Movies    531
# 10                   TV Comedies    517
# 11                     Thrillers    491
# 12                Crime TV Shows    426
# 13                      Kids' TV    411
# 14                    Docuseries    352
# 15             Romantic TV Shows    333
# 16               Stand-Up Comedy    329
# 17              Music & Musicals    321
# 18                 Horror Movies    312
# 19              British TV Shows    231
# 20                    Reality TV    222
# 21              Sci-Fi & Fantasy    218
# ...

# %%
top_15_genres = top_genres_count.head(15)

plt.figure(figsize = (10,6))
sns.barplot(y='genre' , x = 'count' , data = top_15_genres,palette='mako',hue='genre',legend=False)

plt.xlabel('Genre')
plt.ylabel('Number of Titles')
plt.title('Top 15 Genres')
plt.show()

# %% [markdown]
# Insight : "International Movies" is the most common genre tag , highlightings Netflix's global content strategy , This is followed by Dramas , comedies , etc

# %%
top_15_genres
# Out:
#                        genre  count
# 0       International Movies   2437
# 1                     Dramas   2105
# 2                   Comedies   1471
# 3     International TV Shows   1197
# 4              Documentaries    786
# 5         Action & Adventure    721
# 6                  TV Dramas    703
# 7         Independent Movies    673
# 8   Children & Family Movies    532
# 9            Romantic Movies    531
# 10               TV Comedies    517
# 11                 Thrillers    491
# 12            Crime TV Shows    426
# 13                  Kids' TV    411
# 14                Docuseries    352

# %% [markdown]
# ##  4.4 What is the distribution of conetent duration ?

# %%
df.head(2)
# Out:
#   show_id     type title           director  \
# 0      s1  TV Show    3%            Unknown
# 1      s2    Movie  7:19  Jorge Michel Grau
#
#                                                 cast country date_added  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil 2020-08-14
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico 2016-12-23
#
#    release_year rating   duration  \
# 0          2020  TV-MA  4 Seasons
# 1          2016  TV-MA     93 min
#
#                                            listed_in  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
#
#                                          description  year_added  month_added
# 0  In a future where the elite inhabit an island ...        2020            8
# 1  After a devastating earthquake hits Mexico Cit...        2016           12

# %%
movies_df = df[df['type'] == 'Movie'].copy()
webseries_df = df[df['type'] == 'TV Show'].copy()

# %%
## clean and convert duration for movies :

# %%
movies_df.head(2)
# Out:
#   show_id   type  title           director  \
# 1      s2  Movie   7:19  Jorge Michel Grau
# 2      s3  Movie  23:59       Gilbert Chan
#
#                                                 cast    country date_added  \
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...     Mexico 2016-12-23
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...  Singapore 2018-12-20
#
#    release_year rating duration                            listed_in  \
# 1          2016  TV-MA   93 min         Dramas, International Movies
# 2          2011      R   78 min  Horror Movies, International Movies
#
#                                          description  year_added  month_added
# 1  After a devastating earthquake hits Mexico Cit...        2016           12
# 2  When an army recruit is found dead, his fellow...        2018           12

# %%
movies_df['duration'].unique()
# Out:
# array(['93 min', '78 min', '80 min', '123 min', '95 min', '119 min',
#        '118 min', '143 min', '103 min', '89 min', '91 min', '149 min',
#        '144 min', '124 min', '87 min', '110 min', '128 min', '117 min',
#        '100 min', '84 min', '99 min', '90 min', '102 min', '104 min',
#        '105 min', '56 min', '125 min', '81 min', '97 min', '106 min',
#        '107 min', '109 min', '44 min', '75 min', '101 min', '113 min',
#        '114 min', '130 min', '94 min', '140 min', '135 min', '82 min',
#        '70 min', '121 min', '92 min', '164 min', '53 min', '83 min',
#        '116 min', '86 min', '120 min', '96 min', '126 min', '129 min',
#        '77 min', '137 min', '148 min', '28 min', '122 min', '176 min',
#        '85 min', '22 min', '68 min', '111 min', '29 min', '142 min',
#        '168 min', '21 min', '59 min', '20 min', '98 min', '108 min',
#        '76 min', '26 min', '156 min', '30 min', '57 min', '150 min',
# ...

# %%
webseries_df.head(2)
# Out:
#   show_id     type title     director  \
# 0      s1  TV Show    3%      Unknown
# 5      s6  TV Show    46  Serdar Akar
#
#                                                 cast country date_added  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil 2020-08-14
# 5  Erdal Beşikçioğlu, Yasemin Allen, Melis Birkan...  Turkey 2017-07-01
#
#    release_year rating   duration  \
# 0          2020  TV-MA  4 Seasons
# 5          2016  TV-MA   1 Season
#
#                                            listed_in  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 5    International TV Shows, TV Dramas, TV Mysteries
#
#                                          description  year_added  month_added
# 0  In a future where the elite inhabit an island ...        2020            8
# 5  A genetics professor experiments with a treatm...        2017            7

# %%
# as we can see all the values are in <time> min for movies
movies_df['duration_min'] = movies_df['duration'].str.replace(' min','').astype(int)

# for WEB SERIES :
webseries_df['seasons'] = webseries_df['duration'].str.replace(' Seasons' , '').str.replace(' Season' , '').astype(int)

# %%
movies_df.head()
# Out:
#   show_id   type  title           director  \
# 1      s2  Movie   7:19  Jorge Michel Grau
# 2      s3  Movie  23:59       Gilbert Chan
# 3      s4  Movie      9        Shane Acker
# 4      s5  Movie     21     Robert Luketic
# 6      s7  Movie    122    Yasir Al Yasiri
#
#                                                 cast        country  \
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
# 6  Amina Khalil, Ahmed Dawood, Tarek Lotfy, Ahmed...          Egypt
#
#   date_added  release_year rating duration  \
# 1 2016-12-23          2016  TV-MA   93 min
# 2 2018-12-20          2011      R   78 min
# 3 2017-11-16          2009  PG-13   80 min
# 4 2020-01-01          2008  PG-13  123 min
# 6 2020-06-01          2019  TV-MA   95 min
#
# ...

# %%
webseries_df.head()
# Out:
#    show_id     type   title              director  \
# 0       s1  TV Show      3%               Unknown
# 5       s6  TV Show      46           Serdar Akar
# 11     s12  TV Show    1983               Unknown
# 12     s13  TV Show    1994  Diego Enrique Osorno
# 16     s17  TV Show  Feb-09               Unknown
#
#                                                  cast                country  \
# 0   João Miguel, Bianca Comparato, Michel Gomes, R...                 Brazil
# 5   Erdal Beşikçioğlu, Yasemin Allen, Melis Birkan...                 Turkey
# 11  Robert Więckiewicz, Maciej Musiał, Michalina O...  Poland, United States
# 12                                            Unknown                 Mexico
# 16  Shahd El Yaseen, Shaila Sabt, Hala, Hanadi Al-...          United States
#
#    date_added  release_year rating   duration  \
# 0  2020-08-14          2020  TV-MA  4 Seasons
# 5  2017-07-01          2016  TV-MA   1 Season
# 11 2018-11-30          2018  TV-MA   1 Season
# ...

# %%
 # plot the distributions :

 fig ,axes = plt.subplots(1,2 ,figsize=(18,7))

 # movies distribution :
 sns.histplot(ax=axes[0],data=movies_df,x='duration_min',bins=50,kde=True,color='skyblue').set_title("Movies Duration Distribution(minutes)")


 # for webseries :
 sns.histplot(ax=axes[1],data=webseries_df,x='seasons',legend=False).set_title("Webseries Duration Distribution(seasons)")
# Out:
# Text(0.5, 1.0, 'Webseries Duration Distribution(seasons)')

# %% [markdown]
# # 4.5 : Where does the content come from (Geographical Analysis)

# %%
df.head(2)
# Out:
#   show_id     type title           director  \
# 0      s1  TV Show    3%            Unknown
# 1      s2    Movie  7:19  Jorge Michel Grau
#
#                                                 cast country date_added  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil 2020-08-14
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico 2016-12-23
#
#    release_year rating   duration  \
# 0          2020  TV-MA  4 Seasons
# 1          2016  TV-MA     93 min
#
#                                            listed_in  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
#
#                                          description  year_added  month_added
# 0  In a future where the elite inhabit an island ...        2020            8
# 1  After a devastating earthquake hits Mexico Cit...        2016           12

# %%
df['country'].unique()
# Out:
# array(['Brazil', 'Mexico', 'Singapore', 'United States', 'Turkey',
#        'Egypt', 'India', 'Poland, United States', 'Thailand', 'Nigeria',
#        'Norway, Iceland, United States', 'United Kingdom', 'Japan',
#        'South Korea', 'Italy', 'Canada', 'Indonesia', 'Romania', 'Spain',
#        'Iceland', 'South Africa, Nigeria', 'France',
#        'United States, South Africa', 'Portugal, Spain',
#        'Hong Kong, China, Singapore', 'United States, Germany',
#        'South Africa, China, United States', 'Argentina',
#        'United States, France, Serbia', 'Germany',
#        'Denmark, France, Poland', 'Poland', 'Kenya',
#        'New Zealand, United Kingdom', 'Pakistan', 'Australia',
#        'Australia, United States', 'Mexico, United States',
#        'United States, China', 'China, Hong Kong', 'Taiwan',
#        'United States, United Kingdom', 'France, South Korea, Japan',
#        'United States, Canada', 'United Kingdom, United States',
# ...

# %%
countries = df.assign(country=df['country'].str.split(', ')).explode('country')
countries
# Out:
#      show_id     type                                    title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                     7:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7784   s7785    Movie                        Zulu Man in Japan
# 7785   s7786  TV Show                    Zumbo's Just Desserts
# 7786   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
# 7786   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
# 7786   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                director                                               cast  \
# 0               Unknown  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
top_15_countries = countries['country'].value_counts().reset_index()
top_15_countries.columns = ['country','count']
top_15_countries.head(15)
# Out:
#            country  count
# 0    United States   3792
# 1            India    990
# 2   United Kingdom    721
# 3           Canada    412
# 4           France    349
# 5            Japan    285
# 6            Spain    215
# 7      South Korea    212
# 8          Germany    199
# 9           Mexico    154
# 10           China    147
# 11       Australia    142
# 12           Egypt    110
# 13          Turkey    108
# 14       Hong Kong    102

# %%
plt.figure(figsize=(10, 6))
sns.barplot(y='country', x='count', data=top_15_countries.head(15), palette='viridis', hue='country', legend=False)
plt.title('Top 15 Countries by Content Count')
plt.xlabel('Number of Titles')
plt.ylabel('Country')
plt.show()

# %% [markdown]
# ## 4.6 What are the maturity ratings of the content ?

# %%
df.head(2)
# Out:
#   show_id     type title           director  \
# 0      s1  TV Show    3%            Unknown
# 1      s2    Movie  7:19  Jorge Michel Grau
#
#                                                 cast country date_added  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil 2020-08-14
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico 2016-12-23
#
#    release_year rating   duration  \
# 0          2020  TV-MA  4 Seasons
# 1          2016  TV-MA     93 min
#
#                                            listed_in  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
#
#                                          description  year_added  month_added
# 0  In a future where the elite inhabit an island ...        2020            8
# 1  After a devastating earthquake hits Mexico Cit...        2016           12

# %%
plt.figure(figsize=(10, 6))
sns.countplot(data=df, y='rating', order=df['rating'].value_counts().index, palette='viridis', hue='rating', legend=False)
plt.title('Distribution of Content Ratings')
plt.xlabel('Number of Titles')
plt.ylabel('Rating')
plt.show()

# %%
rating_counts = df['rating'].value_counts()

# Select the top 10 ratings and group the rest
top_n = 10
if len(rating_counts) > top_n:
    top_ratings = rating_counts.head(top_n)
    other_count = rating_counts.iloc[top_n:].sum()
    rating_counts = pd.concat([top_ratings, pd.Series([other_count], index=['Other'])])


plt.figure(figsize=(10, 8))
plt.pie(rating_counts, labels=rating_counts.index, autopct='%1.1f%%', startangle=140)
plt.title('Distribution of Content Ratings')
plt.axis('equal') # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()

# %% [markdown]
# Insight : This pie chart shows the proportion of each content rating in the dataset. You can see that the majority of content falls under the 'TV-MA' rating, followed by 'TV-14' and 'TV-PG'. This suggests that a large portion of the content on Netflix is geared towards mature audiences.

# %%
# Step 5 : Feature Engineering - Content Freshness

# %% [markdown]
# ## Step 5 : Feature engineering - content freshneess

# %%
# Let's create a new feature to analyze how old content is when it gets added to Netflix . This can tell us about their acquistion strategy.

# %%
# Create the 'age_on_netflix' feature
df['age_on_netflix'] = df['year_added'] - df['release_year']

# Filter out any potential errors where added_year is before release_year
content_age = df[df['age_on_netflix'] >= 0]

plt.figure(figsize=(14, 7))
sns.histplot(data=content_age, x='age_on_netflix', bins=50, kde=True)
plt.title('Distribution of Content Age When Added to Netflix')
plt.xlabel('Content Age (Years)')
plt.ylabel('Number of Titles')
plt.show()

# %% [markdown]
# **Insight:** The large spike at `0` indicates that a significant amount of content is added in the same year it's released, which is characteristic of "Netflix Originals." However, there is a very long tail, showing that Netflix also heavily invests in acquiring licensed content that can be decades old, building a deep library of classic films and shows.

# %% [markdown]
# # Step 6 : Deeper Multivariate Analysis

# %%
# Analyze movie duration across different top genres
top_genres = genres['genre'].value_counts().index[:5]
genres_movies = genres[(genres['type'] == 'Movie') & (genres['genre'].isin(top_genres))].copy()
genres_movies['duration_min'] = genres_movies['duration'].str.replace(' min', '').astype(int)

plt.figure(figsize=(15, 8))
sns.boxplot(data=genres_movies, x='genre', y='duration_min', palette='pastel', hue='genre', legend=False)
plt.title('Movie Duration by Top Genres')
plt.xlabel('Genre')
plt.ylabel('Duration (minutes)')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# **Insight:** While the median duration for most top genres is similar (around 90-100 minutes), we can see some interesting variations. For example, Dramas tend to have a wider range of durations, with many longer films. International Movies also show a broad distribution, reflecting diverse filmmaking styles from around the world.

# %% [markdown]
# # Step 7 : Word Cloud from Content Descriptions
#
# As a final visual analysis, let's generate a word cloud from the `description` column to see what themes and words are most common in Netflix content.

# %%
# Combine all descriptions into a single string
from wordcloud import WordCloud, STOPWORDS
text = ' '.join(df['description'].dropna())

# Create and generate a word cloud image
stopwords = set(STOPWORDS)
wordcloud = WordCloud(width=800, height=400, background_color='black', stopwords=stopwords).generate(text)

# Display the generated image
plt.figure(figsize=(15, 10))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('Most Common Words in Netflix Content Descriptions', fontsize=20)
plt.show()

# %% [markdown]
# **Insight:** The word cloud highlights common themes and subjects. Words like "life," "family," "love," "young," "friends," and "world" are prominent, suggesting that much of the content revolves around human relationships and personal journeys. Action-oriented words like "find," "secret," and "new" also appear frequently.

# %% [markdown]
# ### Step 8: Final Conclusion and Summary of Insights
#
# This in-depth EDA of the Netflix dataset has revealed several key characteristics and strategies of the platform's content library.
#
# **Key Findings:**
# 1. **Content Strategy:** Netflix's library is movie-heavy (~70%), and the platform aggressively added content between 2016-2019. Their strategy involves a mix of brand new originals (added the same year they are released) and a deep library of licensed older content.
# 2. **Global Dominance:** While the US is the top content producer, the platform is heavily international, with India being a massive contributor. This is reflected in the top genres ("International Movies") and most frequent actors.
# 3. **Target Audience:** The content library is skewed towards mature audiences, with `TV-MA` and `TV-14` being the most common ratings.
# 4. **Content Format & Genre:** Dramas and Comedies are universally popular genres. Most movies stick to a standard 90-120 minute runtime, while the vast majority of TV shows only last for a single season, suggesting a high-risk, high-reward approach to series production.
# 5. **Common Themes:** Descriptions of content frequently revolve around universal themes of life, family, love, and discovery.
#
# **Limitations:** This dataset is a snapshot in time and lacks viewership data. Therefore, our analysis is of the *supply* of content, not its *demand* or popularity. Nonetheless, this EDA provides a strong, multi-faceted understanding of the composition and evolution of the Netflix library.

# %% [markdown]
# Submission Q's :

# %% [markdown]
# * How has the distribution of content ratings changed over time?
# * Is there a relationship between content age and its type (Movie vs. TV Show)?
# * Can we identify any trends in content production based on the release year vs. the year added to Netflix?
# * What are the most common word pairs or phrases in content descriptions?
# * Who are the top directors on Netflix?

# %%
df.head()
# Out:
#   show_id     type  title           director  \
# 0      s1  TV Show     3%            Unknown
# 1      s2    Movie   7:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 cast        country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#   date_added  release_year rating   duration  \
# 0 2020-08-14          2020  TV-MA  4 Seasons
# 1 2016-12-23          2016  TV-MA     93 min
# 2 2018-12-20          2011      R     78 min
# 3 2017-11-16          2009  PG-13     80 min
# 4 2020-01-01          2008  PG-13    123 min
#
# ...

# %% [markdown]
# ## Assignment Questions :

# %% [markdown]
# ## Q 1 : How has the distribution of content ratings changed over time?

# %%
# Group by year added and rating, then unstack to get ratings as columns
rating_over_time = df.groupby(['year_added', 'rating']).size().unstack(fill_value=0)

# Plot the data
plt.figure(figsize=(12, 8))
rating_over_time.plot(kind='area', stacked=True, figsize=(12, 8))
plt.title('Distribution of Content Ratings Over Time')
plt.xlabel('Year Added')
plt.ylabel('Number of Titles')
plt.legend(title='Rating', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %% [markdown]
# **INSIGHT** :
#
#  The stacked area plot shows that the number of titles added with each rating increased significantly from 2016 to 2020. 'TV-MA' and 'TV-14' consistently make up the largest portions of content added each year, indicating Netflix's focus on more mature audiences. There is a noticeable drop in content added across all ratings in 2021

# %% [markdown]
# # Q2 : Is there a relationship between content age and its type (Movie vs. TV Show)?
#
#
# ```
# # This is formatted as code
# ```

# %%
plt.figure(figsize=(12, 7))
sns.boxplot(data=content_age, x='type', y='age_on_netflix', palette='viridis', hue='type', legend=False)
plt.title('Content Age When Added to Netflix by Content Type')
plt.xlabel('Content Type')
plt.ylabel('Content Age (Years)')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.violinplot(data=content_age, x='type', y='age_on_netflix', palette='viridis', hue='type', legend=False)
plt.title('Content Age When Added to Netflix by Content Type (Violin Plot)')
plt.xlabel('Content Type')
plt.ylabel('Content Age (Years)')
plt.show()

# %% [markdown]
# we have two violin shape :  TV Show , and Movie ---> TV show is wider initially at 0 content age(years) that means so many numbers of TV shows are acquired or made by Netflix and some very old show is acquired
#
# while Movie is initially not that much wider , that means number of acquired movies is less , or movies made by NETFLIX is less
#
#
# TV Shows: The distribution is heavily concentrated around an age_on_netflix of 0, with a few outliers extending to older ages. This indicates that most TV shows added to Netflix are relatively new.
#
#
# Movies: The distribution for movies is wider and extends to significantly older ages, showing that Netflix adds a substantial number of movies that were released many years before being added to the platform.

# %% [markdown]
# ## Q3 : Can we identify any trends in content production based on the release year vs. the year added to Netflix?

# %%
plt.figure(figsize=(12, 7))
sns.scatterplot(data=df, x='release_year', y='year_added', hue='type', alpha=0.6)
plt.title('Release Year vs. Year Added to Netflix')
plt.xlabel('Release Year')
plt.ylabel('Year Added to Netflix')
plt.show()

# %%
plt.figure(figsize=(12, 7))
plt.hexbin(df['release_year'], df['year_added'], gridsize=20, cmap='Blues')
plt.colorbar(label='Count')
plt.title('Content Density: Release Year vs. Year Added to Netflix')
plt.xlabel('Release Year')
plt.ylabel('Year Added to Netflix')
plt.show()

# %% [markdown]
# **insight** : here we can see highest count of movies/tv shows in top right corner here , we can see that y-axis(left ) showing Year added to netflix  , while x axis showing release year of that tvshwo/movies  , y-axis (right) show count , we can clearly visualize that in top right corner , we have highest number of added content in year around 2020 , following 2018, and so on

# %% [markdown]
# # Q 4 : What are the most common word pairs or phrases in content descriptions?

# %%
from wordcloud import WordCloud, STOPWORDS
import re
from collections import Counter
import matplotlib.pyplot as plt

text = ' '.join(df['description'].dropna()).lower()
text = re.sub(r'[^a-z\s]', '', text) # Remove non-alphabetic characters

# Tokenize the text and remove stop words
words = text.split()
stopwords = set(STOPWORDS)
filtered_words = [word for word in words if word not in stopwords]

# Create bigrams and join them with an underscore
bigrams = ['_'.join(pair) for pair in zip(filtered_words[:-1], filtered_words[1:])]

# Create a frequency distribution of bigrams
bigram_counts = Counter(bigrams)

# Convert to a dictionary for the wordcloud
bigram_dict = dict(bigram_counts)

# Create and generate a word cloud image from bigrams
wordcloud = WordCloud(width=800, height=400, background_color='black').generate_from_frequencies(bigram_dict)

plt.figure(figsize=(15, 10))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('Most Common Word Pairs (Bigrams) in Netflix Content Descriptions', fontsize=20)
plt.show()

# %% [markdown]
# ## Q 5 : Who are the top directors on Netflix?

# %%
# Count the occurrences of each director
top_directors = df['director'].value_counts().reset_index()
top_directors.columns = ['director', 'count']

top_directors = top_directors[top_directors['director'] != 'Unknown']

print("Top 10 Directors on Netflix:")
display(top_directors.head(10))
# Out:
# Top 10 Directors on Netflix:
#                   director  count
# 1   Raúl Campos, Jan Suter     18
# 2             Marcus Raboy     16
# 3                Jay Karas     14
# 4      Cathy Garcia-Molina     13
# 5          Martin Scorsese     12
# 6          Youssef Chahine     12
# 7              Jay Chapman     12
# 8         Steven Spielberg     10
# 9             David Dhawan      9
# 10        Robert Rodriguez      8
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['count'].plot(kind='hist', bins=20, title='count')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_1['count'].plot(kind='line', figsize=(8, 4), title='count')
# ...

# %%
plt.figure(figsize=(12, 8))
sns.barplot(x='count', y='director', data=top_directors.head(10), palette='viridis', hue='director', legend=False)
plt.title('Top 10 Directors on Netflix by Content Count')
plt.xlabel('Number of Titles')
plt.ylabel('Director')
plt.show()
